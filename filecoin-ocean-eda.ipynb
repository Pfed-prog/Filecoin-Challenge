# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/filecoinoceanchallenge/FilecoinGreenEnergyConsumption-FilecoinGreenEnergyConsumption.csv')

# %%
df.Date = pd.to_datetime(df.Date)
df['year'] = df.Date.dt.year
df.Date = df.Date.dt.strftime('%Y-%m-%d')
df = df.set_index("Date")

# %%
df[df.year==2020].describe()
# Out:
#        Data storage capacity  Data storage capacity added per day  \
# count           1.300000e+02                         1.300000e+02
# mean            9.172850e+08                         1.519408e+07
# std             5.639737e+08                         3.425864e+06
# min             4.984480e+05                         2.053024e+06
# 25%             4.399166e+08                         1.364505e+07
# 50%             8.448714e+08                         1.602704e+07
# 75%             1.380350e+09                         1.787266e+07
# max             1.966270e+09                         2.114131e+07
#
#        Cumulative renewable energy purchases  Energy intensity lower bound  \
# count                           1.300000e+02                    130.000000
# mean                            3.419768e+07                     28.533072
# std                             1.078490e+07                    131.554397
# ...

# %%
df[df.year==2021].describe()
# Out:
#        Data storage capacity  Data storage capacity added per day  \
# count           3.650000e+02                         3.650000e+02
# mean            8.573107e+09                         3.904893e+07
# std             4.594770e+09                         1.302226e+07
# min             1.984233e+09                         1.797949e+07
# 25%             4.364039e+09                         2.751014e+07
# 50%             7.814262e+09                         3.726186e+07
# 75%             1.304972e+10                         5.141136e+07
# max             1.621590e+10                         6.615507e+07
#
#        Cumulative renewable energy purchases  Energy intensity lower bound  \
# count                           3.650000e+02                    365.000000
# mean                            7.626805e+08                      3.192743
# std                             3.976652e+08                      0.809995
# ...

# %%
df[df.year==2022].describe()
# Out:
#        Data storage capacity  Data storage capacity added per day  \
# count           2.890000e+02                         2.890000e+02
# mean            1.989474e+10                         2.242077e+07
# std             2.020504e+09                         7.252472e+06
# min             1.624013e+10                         7.650816e+06
# 25%             1.800405e+10                         1.437181e+07
# 50%             2.022467e+10                         2.431549e+07
# 75%             2.175660e+10                         2.864445e+07
# max             2.270389e+10                         3.458179e+07
#
#        Cumulative renewable energy purchases  Energy intensity lower bound  \
# count                           2.890000e+02                    289.000000
# mean                            1.416390e+09                      1.623427
# std                             3.560490e+07                      0.148454
# ...

# %%
df['Data storage capacity'].max()
# Out:
# 22703885332

# %%
df[df['Data storage capacity']==22703885332]
# Out:
#             Data storage capacity  Data storage capacity added per day  \
# Date
# 2022-10-16            22703885332                              7650816
#
#             Cumulative renewable energy purchases  \
# Date
# 2022-10-16                           1.452033e+09
#
#             Energy intensity lower bound  Energy intensity estimate  \
# Date
# 2022-10-16                       1.34226                   6.298506
#
#             Energy intensity upper bound  Energy consumption rate lower bound  \
# Date
# 2022-10-16                     19.773216                          28381.61543
#
#             Energy consumption rate estimate  \
# Date
# 2022-10-16                       133179.6431
#
#             Energy consumption rate upper bound  \
# Date
# 2022-10-16                          418097.5527
#
#             Energy used to seal data lower bound  \
# Date
# 2022-10-16                           2056.692357
#
#             Energy used to seal data estimate  \
# Date
# ...

# %%
df['Data storage capacity added per day'].max()
# Out:
# 66155072

# %%
df[df['Data storage capacity added per day']==66155072]
# Out:
#             Data storage capacity  Data storage capacity added per day  \
# Date
# 2021-09-10            11738170303                             66155072
#
#             Cumulative renewable energy purchases  \
# Date
# 2021-09-10                           1.081768e+09
#
#             Energy intensity lower bound  Energy intensity estimate  \
# Date
# 2021-09-10                      3.147064                  19.951975
#
#             Energy intensity upper bound  Energy consumption rate lower bound  \
# Date
# 2021-09-10                     47.285131                           34403.7801
#
#             Energy consumption rate estimate  \
# Date
# 2021-09-10                       218115.4482
#
#             Energy consumption rate upper bound  \
# Date
# 2021-09-10                          516922.1405
#
#             Energy used to seal data lower bound  \
# Date
# 2021-09-10                           17783.80646
#
#             Energy used to seal data estimate  \
# Date
# ...

# %%
df[df["Energy intensity estimate"]==df["Energy intensity estimate"].max()]
# Out:
#             Data storage capacity  Data storage capacity added per day  \
# Date
# 2020-08-24                 498448                              2053024
#
#             Cumulative renewable energy purchases  \
# Date
# 2020-08-24                            15734658.47
#
#             Energy intensity lower bound  Energy intensity estimate  \
# Date
# 2020-08-24                   1404.098113                10618.24561
#
#             Energy intensity upper bound  Energy consumption rate lower bound  \
# Date
# 2020-08-24                   21402.98254                           651.804634
#
#             Energy consumption rate estimate  \
# Date
# 2020-08-24                       4929.158175
#
#             Energy consumption rate upper bound  \
# Date
# 2020-08-24                          9935.604259
#
#             Energy used to seal data lower bound  \
# Date
# 2020-08-24                            551.893912
#
#             Energy used to seal data estimate  \
# Date
# ...

# %%
df[df["Energy intensity estimate"]==df["Energy intensity estimate"].min()]
# Out:
#             Data storage capacity  Data storage capacity added per day  \
# Date
# 2022-10-16            22703885332                              7650816
#
#             Cumulative renewable energy purchases  \
# Date
# 2022-10-16                           1.452033e+09
#
#             Energy intensity lower bound  Energy intensity estimate  \
# Date
# 2022-10-16                       1.34226                   6.298506
#
#             Energy intensity upper bound  Energy consumption rate lower bound  \
# Date
# 2022-10-16                     19.773216                          28381.61543
#
#             Energy consumption rate estimate  \
# Date
# 2022-10-16                       133179.6431
#
#             Energy consumption rate upper bound  \
# Date
# 2022-10-16                          418097.5527
#
#             Energy used to seal data lower bound  \
# Date
# 2022-10-16                           2056.692357
#
#             Energy used to seal data estimate  \
# Date
# ...

# %%
# convert to exobytes
df['Data storage capacity'] = df['Data storage capacity'] * 1.073741824E-9

# %%
df.plot(y='Data storage capacity', kind='area')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot(y='Data storage capacity added per day')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[:10].plot(y='Energy intensity estimate')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[100:].plot(y='Energy intensity estimate')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# 1.2

# %%
df["Cumulative renewable energy purchases"].max()
# Out:
# 1452033144.0

# %%
df.plot(y='Cumulative renewable energy purchases', kind='area')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['ren_share'] = df['Cumulative renewable energy purchases']  / df['Cumulative energy use estimate']

# %%
df[5:].plot(y='ren_share', kind='area')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.describe()
# Out:
#        Data storage capacity  Data storage capacity added per day  \
# count             784.000000                         7.840000e+02
# mean               12.323393                         2.896389e+07
# std                 8.314818                         1.395735e+07
# min                 0.000535                         2.053024e+06
# 25%                 3.772380                         1.765826e+07
# 50%                13.258516                         2.671651e+07
# 75%                20.024617                         3.664840e+07
# max                24.378111                         6.615507e+07
#
#        Cumulative renewable energy purchases  Energy intensity lower bound  \
# count                           7.840000e+02                    784.000000
# mean                            8.828581e+08                      6.816098
# std                             5.526074e+08                     54.276706
# ...

# %% [markdown]
# 2

# %%
data = pd.read_csv("/kaggle/input/filecoinoceanchallenge/FIL-USD-FIL-USD.csv",index_col='Date', parse_dates=True)

# %%
df
# Out:
#             Data storage capacity  Data storage capacity added per day  \
# Date
# 2020-08-24               0.000535                              2053024
# 2020-08-25               0.009919                             13984256
# 2020-08-26               0.024217                             13212864
# 2020-08-27               0.039043                             14277536
# 2020-08-28               0.055220                             16174560
# ...                           ...                                  ...
# 2022-10-12              24.327384                             11987424
# 2022-10-13              24.340873                             12611296
# 2022-10-14              24.353995                             12329664
# 2022-10-15              24.367511                             12360032
# 2022-10-16              24.378111                              7650816
#
#             Cumulative renewable energy purchases  \
# Date
# ...

# %%
columns = data.columns

for x in columns:
    df[x] = data["2020-08-24":'2022-10-16'][x].values

# %%
df
# Out:
#             Data storage capacity  Data storage capacity added per day  \
# Date
# 2020-08-24               0.000535                              2053024
# 2020-08-25               0.009919                             13984256
# 2020-08-26               0.024217                             13212864
# 2020-08-27               0.039043                             14277536
# 2020-08-28               0.055220                             16174560
# ...                           ...                                  ...
# 2022-10-12              24.327384                             11987424
# 2022-10-13              24.340873                             12611296
# 2022-10-14              24.353995                             12329664
# 2022-10-15              24.367511                             12360032
# 2022-10-16              24.378111                              7650816
#
#             Cumulative renewable energy purchases  \
# Date
# ...

# %%
correlation_seal = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',"Energy used to seal data estimate"]].corr()
correlation_added = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',"Data storage capacity added per day"]].corr()
correlation_cons = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',"Energy consumption rate estimate"]].corr()
correlation_cons_sp = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',"Energy consumption rate estimate"]].corr('spearman')

# %%
sns.heatmap(correlation_seal, annot=True);

# %%
sns.heatmap(correlation_added, annot=True);

# %%
sns.heatmap(correlation_cons, annot=True);

# %%
sns.heatmap(correlation_cons_sp, annot=True);
